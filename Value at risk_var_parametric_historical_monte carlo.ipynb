# %% [markdown]
# # Value at Risk (VaR) Modeling for Financial Risk Management

# %% [markdown]
# This notebook demonstrates the construction of VaR models using Variance-Covariance, Historical Simulation, and Monte Carlo Simulation methods. It includes backtesting and stress testing procedures to ensure regulatory compliance and evaluate model performance under extreme market conditions.

# %% [markdown]
# #### Imports

# %%
import numpy as np
import pandas as pd
import yfinance as yf

# %% [markdown]
# #### Data Collection

# %%
# Fetch historical data for a specific stock or portfolio
ticker = 'AAPL'
data = yf.download(ticker, start='2020-01-01', end='2021-01-01')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %% [markdown]
# #### Data Preprocessing

# %%
# Calculate daily returns
data['Returns'] = data['Adj Close'].pct_change().dropna()
